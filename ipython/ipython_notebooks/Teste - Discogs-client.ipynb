# %%
import discogs_client as discogs
import os, sys, json
consumer_key ='DBZtVaKjRoxBiCBHdJIA'
consumer_secret = 'BZJafeirxHKrMUpBhjwRZSeVgZhGlOMb'
request_token_url = 'http://api.discogs.com/oauth/request_token'
authorize_url = 'http://www.discogs.com/oauth/authorize'
access_token_url = 'http://api.discogs.com/oauth/access_token'
discogs.user_agent = 'MarcoAMC/0.1 +http://martinscosta.org'

# %%
def get_pasta(pasta):
    ll = os.listdir(pasta)
    return ll

# %%
p = 'G:\mp3\_Classic\Mozart\VA - The Greatest Mozart Collection Ever Made'
get_pasta(p)
# Out:
# ['00 Playlist.m3u',
#  '01. Concerto For Two Pianos & Orchestra In E Flat, K. 365-Allegro.mp3',
#  '02. Piano Concerto No. 21 In C, K. 467-Andante.mp3',
#  '03. Turkish March.mp3',
#  '04. Piano Concerto No. 26 In D, K. 537, Coronation-Larghetto.mp3',
#  '05. Symphony No. 41 In C Major, Kv 551 Jupiter.mp3',
#  '06. Concerto For Piano And Orchestra No.23 In A Major K488 - Adagio.mp3',
#  "07. Sonata For Piano No.1 In A Major - K331 'turkish March.mp3",
#  '08. Concerto For Piano And Orchestra No. 20 In D Minor - K466 - Iii Rondo Allegro Assai.mp3',
#  '09. Concerto For Piano And Orchestra No. 20 In D Minor - K466 - Ii Romanza.mp3',
#  '10. Concerto For Piano And Orchestra No. 20 In D Minor - K466 - I Allegro.mp3',
#  '11. Violin Concerto No. 3 In G, K. 216 - Allegro.mp3',
#  '12. Overture The Magic Flute K. 620.mp3',
#  '13. Concerto For Piano And Orchestra No.23 In A Major - K488 - Allegro (Part 2).mp3',
# ...

# %%
r=discogs.Release('2307013')
print r._id, r.title, r.credits, r.artists, r.labels, r.master, r.tracklist
# Out:
# 2307013
# ...

# %%
r.data
# Out:
# {u'artists': [{u'anv': u'',
#    u'id': 95546,
#    u'join': u'/',
#    u'name': u'Wolfgang Amadeus Mozart',
#    u'resource_url': u'http://api.discogs.com/artists/95546',
#    u'role': u'',
#    u'tracks': u''},
#   {u'anv': u'',
#    u'id': 308115,
#    u'join': u',',
#    u'name': u'Emil Gilels',
#    u'resource_url': u'http://api.discogs.com/artists/308115',
#    u'role': u'',
#    u'tracks': u''},
#   {u'anv': u'',
#    u'id': 1840714,
#    u'join': u',',
#    u'name': u'Elena Gilels',
#    u'resource_url': u'http://api.discogs.com/artists/1840714',
#    u'role': u'',
#    u'tracks': u''},
#   {u'anv': u'',
#    u'id': 283127,
#    u'join': u',',
#    u'name': u'Karl B\xf6hm',
#    u'resource_url': u'http://api.discogs.com/artists/283127',
#    u'role': u'',
#    u'tracks': u''},
#   {u'anv': u'',
#    u'id': 754974,
#    u'join': u'',
#    u'name': u'Wiener Philharmoniker',
#    u'resource_url': u'http://api.discogs.com/artists/754974',
#    u'role': u'',
# ...
